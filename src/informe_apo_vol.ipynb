# %%
using DataFrames, FileIO, DelimitedFiles
using Plots, Optim, LsqFit, JUMD
using Statistics, NamedArrays

# %%
# Get ready
dir_apo_vol = "/home/pbarletta/labo/20/cph_obp/run/apo/cavidad"

nstlim = 12000
phs = collect(2.0:.5:7.5)
idx = collect(1:12)

titrable_resis = [4, 5, 11, 13, 20, 24, 30, 33, 37, 39, 40,
    48, 58, 73, 77, 78, 87, 93, 94, 97, 117]
titrable_resnames = ["GL4", "GL4", "HIP", "GL4", "GL4", "AS4",
    "AS4", "GL4", "AS4", "GL4", "AS4", "GL4", "AS4", "GL4", "AS4",
    "GL4", "AS4", "GL4", "GL4", "HIP", "AS4"]
titrable_cnt = length(titrable_resis)
# Out:
# 21

# %%
for i in 1:12
    PH = convert(Int64, phs[i] * 10)
#     global vol_apo_idx = convert(Array{Float64, 1}, readdlm(joinpath(dir_apo_vol, string(idx[i]),
#             string("vol_trj_apo_", idx[i])))[:, 3])
    global vol_apo_phs = convert(Array{Float64, 1}, readdlm(joinpath(dir_apo_vol, string(phs[i]),
            string("vol_trj_apo_", phs[i])))[:, 3])

#     sym_vol_trj_apo_idx = Symbol("vol_trj_apo_", idx[i])
    sym_vol_trj_apo_phs = Symbol("vol_trj_apo_", PH)
#     eval(:($sym_vol_trj_apo_idx = vol_apo_idx))
    eval(:($sym_vol_trj_apo_phs = vol_apo_phs))
end

# %% [markdown]
# ## vol por pH

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_apo_20, 
        title = string("Volume - pH = ", 2.0), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_apo_20))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_20, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 2.0), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_apo_25, 
        title = string("Volume - pH = ", 2.5), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_apo_25))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_25, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 2.5), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_apo_30, 
        title = string("Volume - pH = ", 3.0), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_apo_30))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_30, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 3.0), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_apo_35, 
        title = string("Volume - pH = ", 3.5), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_apo_35))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_35, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 3.5), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_apo_40, 
        title = string("Volume - pH = ", 4.0), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_apo_40))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_40, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 4.0), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_apo_45, 
        title = string("Volume - pH = ", 4.5), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_apo_45))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_45, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 4.5), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_apo_50, 
        title = string("Volume - pH = ", 5.0), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_apo_50))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_50, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 5.0), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_apo_55, 
        title = string("Volume - pH = ", 5.5), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_apo_55))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_55, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 5.5), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_apo_60, 
        title = string("Volume - pH = ", 6.0), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_apo_60))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_60, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 6.0), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_apo_65, 
        title = string("Volume - pH = ", 6.5), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_apo_65))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_65, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 6.5), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_apo_70, 
        title = string("Volume - pH = ", 7.0), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_apo_70))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_70, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 7.0), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_apo_75, 
        title = string("Volume - pH = ", 7.5), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_apo_75))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_75, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 7.5), yaxis = "Relative probability", xaxis = "Volume")

# %%
vals = vcat([ mean(vol_trj_apo_20) std(vol_trj_apo_20) std(vol_trj_apo_20) / mean(vol_trj_apo_20) ],
[ mean(vol_trj_apo_25) std(vol_trj_apo_25) std(vol_trj_apo_25) / mean(vol_trj_apo_25) ],
[ mean(vol_trj_apo_30) std(vol_trj_apo_30) std(vol_trj_apo_30) / mean(vol_trj_apo_30) ],
[ mean(vol_trj_apo_35) std(vol_trj_apo_35) std(vol_trj_apo_35) / mean(vol_trj_apo_35) ],
[ mean(vol_trj_apo_40) std(vol_trj_apo_40) std(vol_trj_apo_40) / mean(vol_trj_apo_40) ],
[ mean(vol_trj_apo_45) std(vol_trj_apo_45) std(vol_trj_apo_45) / mean(vol_trj_apo_45) ],
[ mean(vol_trj_apo_50) std(vol_trj_apo_50) std(vol_trj_apo_50) / mean(vol_trj_apo_50) ],
[ mean(vol_trj_apo_55) std(vol_trj_apo_55) std(vol_trj_apo_55) / mean(vol_trj_apo_55) ],
[ mean(vol_trj_apo_60) std(vol_trj_apo_60) std(vol_trj_apo_60) / mean(vol_trj_apo_60) ],
[ mean(vol_trj_apo_65) std(vol_trj_apo_65) std(vol_trj_apo_65) / mean(vol_trj_apo_65) ],
[ mean(vol_trj_apo_70) std(vol_trj_apo_70) std(vol_trj_apo_70) / mean(vol_trj_apo_70) ],
[ mean(vol_trj_apo_75) std(vol_trj_apo_75) std(vol_trj_apo_75) / mean(vol_trj_apo_75) ])

NamedArray(vals, (string.(phs), ["μ" ; "std" ; "μ/std"]))
# Out:
# 12×3 Named Array{Float64,2}
# A ╲ B │        μ       std     μ/std
# ──────┼─────────────────────────────
# 2.0   │  289.707   86.9014  0.299962
# 2.5   │  290.428   89.2576  0.307331
# 3.0   │  280.027   87.9128  0.313944
# 3.5   │  267.184   86.0458  0.322047
# 4.0   │  256.564   83.9696  0.327285
# 4.5   │  251.238   85.5069  0.340342
# 5.0   │  249.404   86.3614  0.346271
# 5.5   │  257.452   89.1996  0.346471
# 6.0   │  263.338    92.287  0.350451
# 6.5   │  271.298   101.855  0.375436
# 7.0   │  275.211   107.274  0.389789
# 7.5   │  274.662   111.165  0.404733

# %% [markdown]
# ## vol por idx

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_apo_1,
#         title = string("Volume - idx = ", 1), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_apo_1))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_1, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 1), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_apo_1) std(vol_trj_apo_1) std(vol_trj_apo_1) / mean(vol_trj_apo_1) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_apo_2,
#         title = string("Volume - idx = ", 2), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_apo_2))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_2, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 2), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_apo_2) std(vol_trj_apo_2) std(vol_trj_apo_2) / mean(vol_trj_apo_2) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_apo_3,
#         title = string("Volume - idx = ", 3), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_apo_3))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_3, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 3), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_apo_3) std(vol_trj_apo_3) std(vol_trj_apo_3) / mean(vol_trj_apo_3) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_apo_4,
#         title = string("Volume - idx = ", 4), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_apo_4))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_4, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 4), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_apo_4) std(vol_trj_apo_4) std(vol_trj_apo_4) / mean(vol_trj_apo_4) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_apo_5,
#         title = string("Volume - idx = ", 5), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_apo_5))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_5, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 5), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_apo_5) std(vol_trj_apo_5) std(vol_trj_apo_5) / mean(vol_trj_apo_5) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_apo_6,
#         title = string("Volume - idx = ", 6), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_apo_6))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_6, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 6), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_apo_6) std(vol_trj_apo_6) std(vol_trj_apo_6) / mean(vol_trj_apo_6) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_apo_7,
#         title = string("Volume - idx = ", 7), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_apo_7))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_7, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 7), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_apo_7) std(vol_trj_apo_7) std(vol_trj_apo_7) / mean(vol_trj_apo_7) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_apo_8,
#         title = string("Volume - idx = ", 8), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_apo_8))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_8, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 8), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_apo_8) std(vol_trj_apo_8) std(vol_trj_apo_8) / mean(vol_trj_apo_8) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_apo_9,
#         title = string("Volume - idx = ", 9), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_apo_9))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_9, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 9), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_apo_9) std(vol_trj_apo_9) std(vol_trj_apo_9) / mean(vol_trj_apo_9) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_apo_10,
#         title = string("Volume - idx = ", 10), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_apo_10))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_10, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 10), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_apo_10) std(vol_trj_apo_10) std(vol_trj_apo_10) / mean(vol_trj_apo_10) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_apo_11,
#         title = string("Volume - idx = ", 11), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_apo_11))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_11, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 11), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_apo_11) std(vol_trj_apo_11) std(vol_trj_apo_11) / mean(vol_trj_apo_11) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_apo_12,
#         title = string("Volume - idx = ", 12), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_apo_12))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_apo_12, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 12), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_apo_12) std(vol_trj_apo_12) std(vol_trj_apo_12) / mean(vol_trj_apo_12) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# vals = vcat([ mean(vol_trj_apo_1) std(vol_trj_apo_1) std(vol_trj_apo_1) / mean(vol_trj_apo_1) ],
# [ mean(vol_trj_apo_2) std(vol_trj_apo_2) std(vol_trj_apo_2) / mean(vol_trj_apo_2) ],
# [ mean(vol_trj_apo_3) std(vol_trj_apo_3) std(vol_trj_apo_3) / mean(vol_trj_apo_3) ],
# [ mean(vol_trj_apo_4) std(vol_trj_apo_4) std(vol_trj_apo_4) / mean(vol_trj_apo_4) ],
# [ mean(vol_trj_apo_5) std(vol_trj_apo_5) std(vol_trj_apo_5) / mean(vol_trj_apo_5) ],
# [ mean(vol_trj_apo_6) std(vol_trj_apo_6) std(vol_trj_apo_6) / mean(vol_trj_apo_6) ],
# [ mean(vol_trj_apo_7) std(vol_trj_apo_7) std(vol_trj_apo_7) / mean(vol_trj_apo_7) ],
# [ mean(vol_trj_apo_8) std(vol_trj_apo_8) std(vol_trj_apo_8) / mean(vol_trj_apo_8) ],
# [ mean(vol_trj_apo_9) std(vol_trj_apo_9) std(vol_trj_apo_9) / mean(vol_trj_apo_9) ],
# [ mean(vol_trj_apo_10) std(vol_trj_apo_10) std(vol_trj_apo_10) / mean(vol_trj_apo_10) ])
#
# NamedArray(vals, (string.(idx), ["μ" ; "std" ; "μ/std"]))
