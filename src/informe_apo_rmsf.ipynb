# %%
using DataFrames, FileIO, DelimitedFiles
using Plots, Optim, LsqFit

# %%
# Get ready
home = "/home/pbarletta/labo/20/reobp/"
dir_apo_rmsf = string(home, "run/apo/rmsf/")

aa = 113
nstlim = 12000
phs = collect(2.0:.5:7.5)
idx = collect(1:12)

titrable_resis = [4, 5, 11, 13, 20, 24, 30, 33, 37, 39, 40,
    48, 58, 73, 77, 78, 87, 93, 94, 97, 117]
titrable_resnames = ["GL4", "GL4", "HIP", "GL4", "GL4", "AS4",
    "AS4", "GL4", "AS4", "GL4", "AS4", "GL4", "AS4", "GL4", "AS4",
    "GL4", "AS4", "GL4", "GL4", "HIP", "AS4"]
titrable_cnt = length(titrable_resis)
# Out:
# 21

# %%
for i in 1:length(phs)
    PH = convert(Int64, phs[i] * 10)
#     global rmsf_apo_idx = readdlm(joinpath(dir_apo_rmsf, string(i),
#             string("rmsf_apo_", idx[i])))[2:end, 2]
    global rmsf_apo_ph = readdlm(joinpath(dir_apo_rmsf, string(phs[i]),
            string("rmsf_apo_", phs[i])))[2:end, 2]

#     sym_rmsf_apo_idx = Symbol("rmsf_apo_", idx[i])
    sym_rmsf_apo_ph = Symbol("rmsf_apo_", PH)
#     eval(:($sym_rmsf_apo_idx = rmsf_apo_idx))
    eval(:($sym_rmsf_apo_ph = rmsf_apo_ph))
end

# %% [markdown]
# ## RMSF por pH

# %%
plot(collect(1:aa), rmsf_apo_20,
        title = string("RMSF - pH = ", 2.0), size = (750, 400), label = false,
        ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_apo_25,
        title = string("RMSF - pH = ", 2.5), size = (750, 400), label = false,
        ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_apo_30,
        title = string("RMSF - pH = ", 3.0), size = (750, 400), label = false,
        ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_apo_35,
        title = string("RMSF - pH = ", 3.5), size = (750, 400), label = false,
        ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_apo_40,
        title = string("RMSF - pH = ", 4.0), size = (750, 400), label = false,
        ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_apo_45,
        title = string("RMSF - pH = ", 4.5), size = (750, 400), label = false,
        ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_apo_50,
        title = string("RMSF - pH = ", 5.0), size = (750, 400), label = false,
        ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_apo_55,
        title = string("RMSF - pH = ", 5.5), size = (750, 400), label = false,
        ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_apo_60,
        title = string("RMSF - pH = ", 6.0), size = (750, 400), label = false,
        ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_apo_65,
        title = string("RMSF - pH = ", 6.5), size = (750, 400), label = false,
        ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_apo_70,
        title = string("RMSF - pH = ", 7.0), size = (750, 400), label = false,
        ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_apo_75,
        title = string("RMSF - pH = ", 7.5), size = (750, 400), label = false,
        ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# ## RMSF por idx

# %% [markdown]
# plot(collect(1:aa), rmsf_apo_1,
#         title = string("RMSF - idx = ", 1), size = (750, 400), label = false,
#         ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# plot(collect(1:aa), rmsf_apo_2,
#         title = string("RMSF - idx = ", 2), size = (750, 400), label = false,
#         ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# plot(collect(1:aa), rmsf_apo_3,
#         title = string("RMSF - idx = ", 3), size = (750, 400), label = false,
#         ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# plot(collect(1:aa), rmsf_apo_4,
#         title = string("RMSF - idx = ", 4), size = (750, 400), label = false,
#         ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# plot(collect(1:aa), rmsf_apo_5,
#         title = string("RMSF - idx = ", 5), size = (750, 400), label = false,
#         ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# plot(collect(1:aa), rmsf_apo_6,
#         title = string("RMSF - idx = ", 6), size = (750, 400), label = false,
#         ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# plot(collect(1:aa), rmsf_apo_7,
#         title = string("RMSF - idx = ", 7), size = (750, 400), label = false,
#         ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# plot(collect(1:aa), rmsf_apo_8,
#         title = string("RMSF - idx = ", 8), size = (750, 400), label = false,
#         ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# plot(collect(1:aa), rmsf_apo_9,
#         title = string("RMSF - idx = ", 9), size = (750, 400), label = false,
#         ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# plot(collect(1:aa), rmsf_apo_10,
#         title = string("RMSF - idx = ", 10), size = (750, 400), label = false,
#         ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# plot(collect(1:aa), rmsf_apo_11,
#         title = string("RMSF - idx = ", 11), size = (750, 400), label = false,
#         ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# plot(collect(1:aa), rmsf_apo_12,
#         title = string("RMSF - idx = ", 12), size = (750, 400), label = false,
#         ylims = (0, +Inf), xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")
