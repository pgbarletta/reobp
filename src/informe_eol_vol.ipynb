# %%
using DataFrames, FileIO, DelimitedFiles
using Plots, Optim, LsqFit, JUMD
using Statistics, NamedArrays

# %%
# Get ready
dir_eol_vol = "/home/pbarletta/labo/20/cph_obp/run/eol/cavidad"

nstlim = 12000
phs = collect(2.0:.5:7.5)
idx = collect(1:12)

titrable_resis = [4, 5, 11, 13, 20, 24, 30, 33, 37, 39, 40,
    48, 58, 73, 77, 78, 87, 93, 94, 97, 117]
titrable_resnames = ["GL4", "GL4", "HIP", "GL4", "GL4", "AS4",
    "AS4", "GL4", "AS4", "GL4", "AS4", "GL4", "AS4", "GL4", "AS4",
    "GL4", "AS4", "GL4", "GL4", "HIP", "AS4"]
titrable_cnt = length(titrable_resis)
# Out:
# 21

# %%
for i in 1:12
    PH = convert(Int64, phs[i] * 10)
#     global vol_eol_idx = convert(Array{Float64, 1}, readdlm(joinpath(dir_eol_vol, string(idx[i]),
#             string("vol_trj_eol_", idx[i])))[:, 3])
    global vol_eol_phs = convert(Array{Float64, 1}, readdlm(joinpath(dir_eol_vol, string(phs[i]),
            string("vol_trj_eol_", phs[i])))[:, 3])

#     sym_vol_trj_eol_idx = Symbol("vol_trj_eol_", idx[i])
    sym_vol_trj_eol_phs = Symbol("vol_trj_eol_", PH)
#     eval(:($sym_vol_trj_eol_idx = vol_eol_idx))
    eval(:($sym_vol_trj_eol_phs = vol_eol_phs))
end

# %% [markdown]
# ## vol por pH

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_eol_20, 
        title = string("Volume - pH = ", 2.0), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_eol_20))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_20, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 2.0), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_eol_25, 
        title = string("Volume - pH = ", 2.5), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_eol_25))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_25, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 2.5), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_eol_30, 
        title = string("Volume - pH = ", 3.0), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_eol_30))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_30, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 3.0), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_eol_35, 
        title = string("Volume - pH = ", 3.5), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_eol_35))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_35, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 3.5), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_eol_40, 
        title = string("Volume - pH = ", 4.0), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_eol_40))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_40, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 4.0), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_eol_45, 
        title = string("Volume - pH = ", 4.5), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_eol_45))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_45, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 4.5), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_eol_50, 
        title = string("Volume - pH = ", 5.0), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_eol_50))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_50, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 5.0), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_eol_55, 
        title = string("Volume - pH = ", 5.5), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_eol_55))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_55, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 5.5), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_eol_60, 
        title = string("Volume - pH = ", 6.0), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_eol_60))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_60, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 6.0), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_eol_65, 
        title = string("Volume - pH = ", 6.5), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_eol_65))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_65, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 6.5), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_eol_70, 
        title = string("Volume - pH = ", 7.0), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_eol_70))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_70, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 7.0), yaxis = "Relative probability", xaxis = "Volume")

# %%
plot(collect(1:nstlim) ./ 100, vol_trj_eol_75, 
        title = string("Volume - pH = ", 7.5), size = (750, 400),
        ylims = (1, 2000), label = false,
        linecolor = Colors.colorant"Brown",
        yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %%
max_vol = 2000
        st = 20
        bin_vol = collect(0:st:max_vol)
        wgh_vol = fill(1.0, length(vol_trj_eol_75))
        
        # Histograma ponderado
        Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_75, bin_vol, wgh_vol, true, false);
        
        bar(Wbins_vol, Whis_vol,
            xlims = (0, 800), ylims = (0, .2),
            xticks = 100:100:700,
            linecolor = false, fillcolor = Colors.colorant"Brown",
            grid = false, legend = false,
            guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
            legendfont = font(12, "Arial"),
            title = string("Volume histogram - pH = ", 7.5), yaxis = "Relative probability", xaxis = "Volume")

# %%
vals = vcat([ mean(vol_trj_eol_20) std(vol_trj_eol_20) std(vol_trj_eol_20) / mean(vol_trj_eol_20) ],
[ mean(vol_trj_eol_25) std(vol_trj_eol_25) std(vol_trj_eol_25) / mean(vol_trj_eol_25) ],
[ mean(vol_trj_eol_30) std(vol_trj_eol_30) std(vol_trj_eol_30) / mean(vol_trj_eol_30) ],
[ mean(vol_trj_eol_35) std(vol_trj_eol_35) std(vol_trj_eol_35) / mean(vol_trj_eol_35) ],
[ mean(vol_trj_eol_40) std(vol_trj_eol_40) std(vol_trj_eol_40) / mean(vol_trj_eol_40) ],
[ mean(vol_trj_eol_45) std(vol_trj_eol_45) std(vol_trj_eol_45) / mean(vol_trj_eol_45) ],
[ mean(vol_trj_eol_50) std(vol_trj_eol_50) std(vol_trj_eol_50) / mean(vol_trj_eol_50) ],
[ mean(vol_trj_eol_55) std(vol_trj_eol_55) std(vol_trj_eol_55) / mean(vol_trj_eol_55) ],
[ mean(vol_trj_eol_60) std(vol_trj_eol_60) std(vol_trj_eol_60) / mean(vol_trj_eol_60) ],
[ mean(vol_trj_eol_65) std(vol_trj_eol_65) std(vol_trj_eol_65) / mean(vol_trj_eol_65) ],
[ mean(vol_trj_eol_70) std(vol_trj_eol_70) std(vol_trj_eol_70) / mean(vol_trj_eol_70) ],
[ mean(vol_trj_eol_75) std(vol_trj_eol_75) std(vol_trj_eol_75) / mean(vol_trj_eol_75) ])

NamedArray(vals, (string.(phs), ["μ" ; "std" ; "μ/std"]))
# Out:
# 12×3 Named Array{Float64,2}
# A ╲ B │        μ       std     μ/std
# ──────┼─────────────────────────────
# 2.0   │  448.831   164.976  0.367568
# 2.5   │  444.456   160.701  0.361567
# 3.0   │  433.327   145.355  0.335439
# 3.5   │  414.021   122.978  0.297032
# 4.0   │  398.828   94.6772  0.237389
# 4.5   │  391.088   85.4922  0.218601
# 5.0   │   384.53   76.9312  0.200066
# 5.5   │  378.033    74.516  0.197115
# 6.0   │  375.379   75.1261  0.200134
# 6.5   │  375.519   75.4942   0.20104
# 7.0   │  376.374   79.1349  0.210256
# 7.5   │  380.855   86.8475  0.228033

# %% [markdown]
# ## vol por idx

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_eol_1,
#         title = string("Volume - idx = ", 1), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_eol_1))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_1, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 1), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_eol_1) std(vol_trj_eol_1) std(vol_trj_eol_1) / mean(vol_trj_eol_1) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_eol_2,
#         title = string("Volume - idx = ", 2), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_eol_2))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_2, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 2), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_eol_2) std(vol_trj_eol_2) std(vol_trj_eol_2) / mean(vol_trj_eol_2) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_eol_3,
#         title = string("Volume - idx = ", 3), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_eol_3))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_3, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 3), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_eol_3) std(vol_trj_eol_3) std(vol_trj_eol_3) / mean(vol_trj_eol_3) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_eol_4,
#         title = string("Volume - idx = ", 4), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_eol_4))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_4, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 4), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_eol_4) std(vol_trj_eol_4) std(vol_trj_eol_4) / mean(vol_trj_eol_4) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_eol_5,
#         title = string("Volume - idx = ", 5), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_eol_5))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_5, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 5), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_eol_5) std(vol_trj_eol_5) std(vol_trj_eol_5) / mean(vol_trj_eol_5) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_eol_6,
#         title = string("Volume - idx = ", 6), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_eol_6))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_6, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 6), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_eol_6) std(vol_trj_eol_6) std(vol_trj_eol_6) / mean(vol_trj_eol_6) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_eol_7,
#         title = string("Volume - idx = ", 7), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_eol_7))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_7, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 7), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_eol_7) std(vol_trj_eol_7) std(vol_trj_eol_7) / mean(vol_trj_eol_7) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_eol_8,
#         title = string("Volume - idx = ", 8), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_eol_8))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_8, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 8), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_eol_8) std(vol_trj_eol_8) std(vol_trj_eol_8) / mean(vol_trj_eol_8) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_eol_9,
#         title = string("Volume - idx = ", 9), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_eol_9))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_9, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 9), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_eol_9) std(vol_trj_eol_9) std(vol_trj_eol_9) / mean(vol_trj_eol_9) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_eol_10,
#         title = string("Volume - idx = ", 10), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_eol_10))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_10, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 10), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_eol_10) std(vol_trj_eol_10) std(vol_trj_eol_10) / mean(vol_trj_eol_10) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_eol_11,
#         title = string("Volume - idx = ", 11), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_eol_11))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_11, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 11), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_eol_11) std(vol_trj_eol_11) std(vol_trj_eol_11) / mean(vol_trj_eol_11) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# plot(collect(1:nstlim) ./ 100, vol_trj_eol_12,
#         title = string("Volume - idx = ", 12), size = (750, 400),
#         ylims = (1, 2000), label = false,
#         linecolor = Colors.colorant"CornflowerBlue",
#         yaxis = "Volume [A3]", xaxis = "Time [ns]")

# %% [markdown]
# max_vol = 2000
#     st = 20
#     bin_vol = collect(0:st:max_vol)
#     wgh_vol = fill(1.0, length(vol_trj_eol_12))
#
#     # Histograma ponderado
#     Wbins_vol, Whis_vol = JUMD.weightedHist(vol_trj_eol_12, bin_vol, wgh_vol, true, false);
#
#     bar(Wbins_vol, Whis_vol,
#         xlims = (0, 800), ylims = (0, .2),
#         xticks = 100:100:700,
#         linecolor = false, fillcolor = Colors.colorant"CornflowerBlue",
#         grid = false, legend = false,
#         guidefont = font(18, "Arial"), tickfont = font(12, "Arial"),
#         legendfont = font(12, "Arial"),
#         title = string("Volume histogram - idx = ", 12), yaxis = "Relative probability", xaxis = "Volume")

# %% [markdown]
# NamedArray([ mean(vol_trj_eol_12) std(vol_trj_eol_12) std(vol_trj_eol_12) / mean(vol_trj_eol_12) ],
#     (["Volume"], ["μ" ; "std" ; "μ/std"]))

# %% [markdown]
# vals = vcat([ mean(vol_trj_eol_1) std(vol_trj_eol_1) std(vol_trj_eol_1) / mean(vol_trj_eol_1) ],
# [ mean(vol_trj_eol_2) std(vol_trj_eol_2) std(vol_trj_eol_2) / mean(vol_trj_eol_2) ],
# [ mean(vol_trj_eol_3) std(vol_trj_eol_3) std(vol_trj_eol_3) / mean(vol_trj_eol_3) ],
# [ mean(vol_trj_eol_4) std(vol_trj_eol_4) std(vol_trj_eol_4) / mean(vol_trj_eol_4) ],
# [ mean(vol_trj_eol_5) std(vol_trj_eol_5) std(vol_trj_eol_5) / mean(vol_trj_eol_5) ],
# [ mean(vol_trj_eol_6) std(vol_trj_eol_6) std(vol_trj_eol_6) / mean(vol_trj_eol_6) ],
# [ mean(vol_trj_eol_7) std(vol_trj_eol_7) std(vol_trj_eol_7) / mean(vol_trj_eol_7) ],
# [ mean(vol_trj_eol_8) std(vol_trj_eol_8) std(vol_trj_eol_8) / mean(vol_trj_eol_8) ],
# [ mean(vol_trj_eol_9) std(vol_trj_eol_9) std(vol_trj_eol_9) / mean(vol_trj_eol_9) ],
# [ mean(vol_trj_eol_10) std(vol_trj_eol_10) std(vol_trj_eol_10) / mean(vol_trj_eol_10) ])
#
# NamedArray(vals, (string.(idx), ["μ" ; "std" ; "μ/std"]))
